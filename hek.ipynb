# %% [markdown]
# <a href="https://colab.research.google.com/github/khalid-shaik/HELLO-WELOCOME/blob/main/hek.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello khalid")
# Out:
# Hello khalid
